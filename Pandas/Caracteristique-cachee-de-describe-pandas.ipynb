# %% [markdown]
# # Une caractéristique cachée de la méthode describe de Pandas

# %%
import pandas as pd

# %%
df = pd.DataFrame([[1, 2, 'A', 'D'],
                   [3, 4, 'B', 'E'],
                   [5, 6, 'A', 'E']], 
                   columns = ['col1', 'col2', 'col3', 'col4'])

# %%
df
# Out:
#    col1  col2 col3 col4
# 0     1     2    A    D
# 1     3     4    B    E
# 2     5     6    A    E

# %%
df.describe()   ## Aucune colonne catégorielle
# Out:
#        col1  col2
# count   3.0   3.0
# mean    3.0   4.0
# std     2.0   2.0
# min     1.0   2.0
# 25%     2.0   3.0
# 50%     3.0   4.0
# 75%     4.0   5.0
# max     5.0   6.0

# %%
df.describe(include = "all")   ## Inclut les colonnes catégorielles
# Out:
#         col1  col2 col3 col4
# count    3.0   3.0    3    3
# unique   NaN   NaN    2    2
# top      NaN   NaN    A    E
# freq     NaN   NaN    2    2
# mean     3.0   4.0  NaN  NaN
# std      2.0   2.0  NaN  NaN
# min      1.0   2.0  NaN  NaN
# 25%      2.0   3.0  NaN  NaN
# 50%      3.0   4.0  NaN  NaN
# 75%      4.0   5.0  NaN  NaN
# max      5.0   6.0  NaN  NaN
