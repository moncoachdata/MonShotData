# %% [markdown]
# # Créer des tracés esquissés à la main avec une ligne Python

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
import logging
logging.getLogger('matplotlib.font_manager').disabled = True

# %%
df = pd.DataFrame({
    "Produit A":[5,6,3,6],
    "Produit B": [4, 1, 1, 8]},
                  index = ["Q1", "Q2", "Q3", "Q4"]
                 )

# %%
with plt.xkcd():
    # ce diagramme sera de style XKCD
    df.plot.bar()
