# %% [markdown]
# # Les diagrammes à hexagones, une alternative plus riche aux diagrammes de dispersion

# %%
import pandas as pd

# %%
df = pd.read_csv("../_datasets/exemple_diagramme_hexbin.csv")

# %% [markdown]
# ## Scatter

# %%
df.plot(kind = 'scatter', x = 'x' , y = 'y');

# %% [markdown]
# ## Hexbin

# %%
df.plot(kind = 'hexbin',
        x = 'x',
        y = 'y', 
        gridsize = 13);
