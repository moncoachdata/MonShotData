# %% [markdown]
# # Rends tes tracés Matplotlib plus professionnels

# %%
# !pip install scienceplots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def model(x, p):
    return x ** (2 * p + 1) / (1 + x ** (2 * p))

# %%
pparam = dict(xlabel='Tension (mV)', ylabel=r'Courant ($\mu$A))')

x = np.linspace(0.75, 1.25, 201)

fig, ax = plt.subplots()
for p in [10, 15, 20, 30, 50, 100]:
    ax.plot(x, model(x, p), label=p)
ax.legend(title='Ordre')
ax.autoscale(tight=True)
ax.set(**pparam);

# %%
import scienceplots

plt.style.use(['science','no-latex']) 
## si tu souhaites utiliser du latex, suis ces instructions : 
## https://github.com/garrettj403/SciencePlots/wiki/FAQ#installing-latex

# %%
pparam = dict(xlabel='Tension (mV)', ylabel=r'Courant ($\mu$A))')

x = np.linspace(0.75, 1.25, 201)

fig, ax = plt.subplots()
for p in [10, 15, 20, 30, 50, 100]:
    ax.plot(x, model(x, p), label=p)
ax.legend(title='Ordre')
ax.autoscale(tight=True)
ax.set(**pparam);
