# %% [markdown]
# # Les limites de Heatmap qui ralentissent tes analyses de données

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Création de données

# %%
rows = 6
cols = 5

# Créer un échantillon de données avec trois groupes de variables
cluster_1 = np.random.normal(loc=0, scale=1, size=(rows, cols))
cluster_2 = np.random.normal(loc=5, scale=1, size=(rows, cols))
cluster_3 = np.random.normal(loc=10, scale=1, size=(rows, cols))

data = np.concatenate([cluster_1, cluster_2, cluster_3], axis=1)
columns = ['var_{}'.format(i) for i in range(3*cols)]

df = pd.DataFrame(data, columns=columns)
df = df.sample(df.shape[0])
df = df.sample(df.shape[1], axis = 1)
df.columns = [f"Col {i}" for i in range(1, df.shape[1]+1)]
df.index = [f"Patient {i}" for i in range(1, df.shape[0]+1)]
df.head()
# Out:
#               Col 1     Col 2      Col 3      Col 4     Col 5      Col 6  \
# Patient 1 -0.031766 -1.532720  11.213869  10.696934  4.629854   9.656757
# Patient 2 -1.383659  0.841553   9.638736  11.008518  5.724534   9.741160
# Patient 3 -0.733289  2.067338   8.676973  10.319894  4.598236   8.199545
# Patient 4  0.672506  0.164000  10.441485   8.969892  4.169486  10.668272
# Patient 5  1.560979  3.006217  10.949588  10.037251  4.566624  11.241949
#
#                Col 7     Col 8     Col 9    Col 10    Col 11    Col 12  \
# Patient 1   9.801194 -0.344636  5.552005  5.256170 -0.203009 -0.777681
# Patient 2  12.021303 -0.996753  6.188834  6.136723 -0.414851  1.679230
# Patient 3  12.012631 -2.086617  5.492211  7.255219  1.137598  0.404160
# Patient 4  10.872477 -1.253289  4.300448  4.830132  0.544173 -0.726880
# Patient 5   9.347144 -0.525249  5.944275  4.630882  2.360105  0.113622
#
#              Col 13     Col 14    Col 15
# Patient 1  6.174529  10.678293  3.644619
# Patient 2  4.827649   9.246982  5.653181
# Patient 3  5.611203  10.711666  5.973611
# Patient 4  4.994788  10.844902  5.211580
# Patient 5  3.672350  10.071654  5.297465

# %%
# Créer une carte thermique classique
plt.figure(figsize=(10, 4))
sns.heatmap(df, cmap='coolwarm', linewidths=0.5);

# %%
sns.clustermap(df, cmap='coolwarm', figsize = (10, 7));
