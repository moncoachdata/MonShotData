# %% [markdown]
# # Une technique efficace mais sous-estimée pour améliorer la performance des modèles

# %%
# !pip install imgaug

# %%
import numpy as np
import matplotlib.pyplot as plt
import imgaug as ia
import imgaug.augmenters as iaa

ia.seed(1)

# %%
images = np.array(
    [ia.quokka(size=(256, 256)) for _ in range(4)], dtype=np.uint8)

# %%
fig, axs = plt.subplots(2, 2, figsize=(3, 3))
for ax, image in zip(axs.flat, images):
    ax.imshow(image, cmap='gray')
    ax.axis('off')
plt.subplots_adjust(hspace=0, wspace=0)
plt.show()

# %%
seq = iaa.Sequential([
    iaa.Fliplr(0.5), # retournements horizontaux
    iaa.Rotate(rotate=(-5,-20)),
    iaa.Affine(
        scale={"x": (0.8, 1.2), "y": (0.8, 1.2)},
        translate_percent={"x": (-0.2, 0.2), "y": (-0.2, 0.2)},
        rotate=(-25, 25),
        shear=(-8, 8))
], random_order=True) # appliquer les augmentateurs dans un ordre aléatoire

# %%
images_aug = seq(images=images)

# %%
fig, axs = plt.subplots(2, 2, figsize=(3, 3))
for ax, image in zip(axs.flat, images_aug):
    ax.imshow(image, cmap='gray')
    ax.axis('off')
plt.subplots_adjust(hspace=0, wspace=0)
plt.show()
